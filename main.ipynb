# %%
from constants import TARGET_TICKER, INTERVAL, CALL_DELAY_SECONDS
from utils.get_max_available_share_price_data import get_max_available_share_price_data

csv_path, calls = get_max_available_share_price_data(
    target_ticker=TARGET_TICKER,
    interval=INTERVAL,
    delay_seconds=CALL_DELAY_SECONDS,
)

print("\nSaved file:")
print(f"- Max-available file ({INTERVAL}): {csv_path}")
# Out:
# CALL 1: yf.Ticker('TSLA').history(period='7d', interval='1m', auto_adjust=False)
# SUCCESS: Downloaded 2682 rows for TSLA at interval '1m'.
# CSV saved to: /Users/kristopherpepper/Documents/jupyterProjects/historicalStockDataDownload/downloads/TSLA_1m_max_20260223_221131.csv
#
# Calls made:
# 1. {'timestamp': '2026-02-23T22:11:28', 'method': 'yf.Ticker().history', 'ticker': 'TSLA', 'time_frame': '7d', 'delay_seconds': 1.0, 'status': 'success', 'rows': 2682, 'interval': '1m', 'csv_path': 'downloads/TSLA_1m_max_20260223_221131.csv'}
#
# Saved file:
# - Max-available file (1m): downloads/TSLA_1m_max_20260223_221131.csv
